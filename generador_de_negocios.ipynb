# %%
# Creating some synthetic data for fine-tuning 
# We are going to create serveral characters for video games in here: 

import os
import openai
import pandas as pd

# Set your OpenAI API key
openai.api_key = os.getenv("OPENAI_API_KEY")

# Define input values
negocios = ['B2B', 'B2C'] 
industrias = ['clinicas', 'inmobiliaria']
ubicaciones = ['madrid','londres'] 

# Create an empty list to store results
results = []

# Loop through input values
record_number = 1
for negocio in negocios:
    for industria in industrias:
        for ubicacion in ubicaciones:
            # Define the prompt with placeholders
            prompt = f"Escribe en un máximo de 50 palabras una idea original para un negocio SaaS {negocio} muy innovador en el sector de {industria}, ubicada en {ubicacion} siguiendo estas instrucciones por líneas: Nombre y claim para la startup: corto y catchy, Idea de negocio: describe el valor añadido concreto y la diferenciación del software, Plataforma: Describe qué tecnología vas a usar, y el tiempo que llevará llegar al primero producto vendible, Marketing y Ventas: Indica a quien se dirige, qué estrategias de marketing usarás para llegar a ese público y cuanto esperas facturar el primer año, Equipo: Describe al equipo emprendedor, Financiación: Escribe brevemente las rondas que vas a necesitar de seed capital para desarrollar el producto, y series A para empezar a vender. Escribe como el propio emprendedor, con todo apasionado y profesional.  "

            # Generate the response using OpenAI's GPT-3 model
            response = openai.Completion.create(
                model="text-davinci-003",
                prompt=prompt,
                temperature=0.7,  # Adjust temperature for response creativity
                max_tokens=500,  
                frequency_penalty=0,
                n=1,  # Generate a single response
                stop=None,  # Let the model determine when to stop
            )

            # Extract and store the response text
            response_text = response.choices[0].text.strip()

            # Create a subprompt string
            subprompt = f"{negocio}, {industria}, {ubicacion}"

            # Store the results in a dictionary
            result = {
                'record number': record_number,
                'negocio': negocio,
                'industria': industria,
                'ubicacion': ubicacion,
                'prompt': prompt,
                'subprompt': subprompt,
                'response': response_text
            }

            results.append(result)

            # Increment the record number
            record_number += 1

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
df.to_csv("saas.csv", index=False)

# %%
import textwrap

# Assuming you have a DataFrame named 'df' with a column named 'response'
for paragraph in df['response']:
    paragraphs = paragraph.split('\n')  # Split by line breaks
    for p in paragraphs:
        wrapped_paragraphs = textwrap.wrap(p, width=80)  # Adjust the width as needed
        for wrapped_p in wrapped_paragraphs:
            print(wrapped_p)
    print('-' * 50)  # Add a line break separator
# Out:
# Nombre y claim para la startup: "CliniX, Experiencia de Salud Digital".
# Idea de negocio: Ofrecemos un software SaaS B2B que conecta las clinicas con los
# pacientes, permitiendo una gestión 100% digital. Esto incluye desde la toma de
# datos, citas y seguimiento digital de los pacientes. Ofrecemos una solución
# única ya que optimizamos el proceso de atención y pago.
# Plataforma: Usaremos tecnología de vanguardia para construir la plataforma, y
# nos comprometemos a tener la primera versión del producto vendible en 6 meses.
# Marketing y Ventas: Nuestro público objetivo son clinicas ubicadas en Madrid que
# quieren mejorar su experiencia digital y ofrecer un mejor servicio a sus
# pacientes. Usaremos distintas estrategias de marketing para llegar a ellos, y
# esperamos facturar 0,5M€ el primer año.
# Equipo: Somos un equipo de 4 emprendedores con experiencia en tecnología,
# marketing y ventas, comprometidos a llevar adelante esta idea innovadora.
# Financiación: Necesitaremos una ronda de seed capital para desarrollar el
# producto, y series A para empezar a vender. Estamos convencidos de que nuestro
# proyecto tendrá éxito y vemos con optimismo el futuro.
# --------------------------------------------------
# Nombre: Dental Software. Claim: "Gestiona tus clínicas dentales con la
# tecnología de vanguardia".
# Idea de negocio: Dental Software es un software B2B que ayuda a clínicas
# dentales a gestionar sus negocios de manera ágil y eficiente. Ofrece una
# solución completa para la administración, el análisis y la optimización de la
# gestión de la clínica. Además, integra funcionalidades como la fidelización de
# pacientes, la comunicación con los proveedores, la gestión de citas, el control
# de stock de materiales, etc.
# Plataforma: Usamos tecnología web y móvil para ofrecer una experiencia completa.
# Estimamos que tardaremos 6 meses en sacar el primer producto vendible.
# Marketing y Ventas: Nuestro objetivo es llegar a clínicas dentales de Londres.
# Para ello, utilizaremos estrategias de marketing digital, promociones y
# publicidad online. Esperamos facturar un total de 400.000 libras el primer año.
# Equipo: Somos un equipo de emprendedores con amplia experiencia en el sector de
# la salud. Contamos con expertos en tecnología, desarrollo, marketing y ventas.
# Financiación: Necesitamos una ronda de seed capital para desarrollar el producto
# y una ronda de series A para arrancar con el modelo de negocio.
# --------------------------------------------------
# Nombre y claim para la startup: RealHome Insight: Explora el futuro
# inmobiliario.
# Idea de negocio: RealHome Insight ofrece una solución SaaS B2B que permite a los
# profesionales de la inmobiliaria estudiar el mercado de una manera más eficiente
# y con mayor precisión. Nuestra herramienta ofrece análisis de calidad y datos
# inmobiliarios actualizados, así como información de mercado, tendencias,
# predicciones y recomendaciones personalizadas.
# Plataforma: Utilizaremos la última tecnología de Inteligencia Artificial,
# Machine Learning y Big Data para desarrollar y ofrecer nuestro software. Estamos
# comprometidos a entregar nuestro producto en un plazo de 18 meses.
# Marketing y Ventas: Estamos enfocados en profesionales de la inmobiliaria en
# Madrid, y emplearemos estrategias de marketing tradicionales, publicidad
# digital, redes sociales y eventos para llegar a ellos. Esperamos facturar al
# menos 1.000.000€ el primer año.
# Equipo: Nuestro equipo emprendedor está compuesto por tres profesionales, un
# especialista en Big Data, uno en Inteligencia Artificial y yo, un experto en
# inmobiliaria.
# Financiación: Necesitaremos 3 rondas de seed capital para desarrollar el
# producto, seguido de una ronda de series A para empezar a vender.
# --------------------------------------------------
# Nombre: Homely. Claim: "Tu mejor inversión".
# Idea de negocio: Homely ofrece un software SaaS B2B para el sector inmobiliario
# londinense. El software, basado en la última tecnología, permite a los usuarios
# analizar y comparar datos de inmuebles con el fin de tomar decisiones de
# inversión informadas. Estamos aportando un valor añadido porque nuestra
# plataforma ofrece una visión mucho más profunda, unificando el análisis de datos
# de todos los sectores de la industria inmobiliaria.
# Plataforma: Usaremos la última tecnología para construir una plataforma de
# análisis de datos extremadamente avanzada. Estimamos que el producto estará
# listo para presentarse en el mercado en unos 6 a 9 meses.
# Marketing y Ventas: Nuestra plataforma de análisis de datos se dirige a
# inversores inmobiliarios y empresas inmobiliarias en Londres. Aplicaremos
# estrategias de marketing digitales para llegar al público objetivo y esperamos
# generar una facturación de al menos 1 millón de libras esterlinas durante el
# primer año.
# Equipo: El equipo emprendedor está compuesto por 4 miembros: un científico de
# datos (CEO), un desarrollador web, un especialista en marketing digital y un
# experto en finanzas. Todos los miembros del equipo están comprometidos a hacer
# de Homely una empresa de éxito.
# Financiación: Necesitamos una ronda de financiación de semilla para desarrollar
# el producto, seguida de una ronda de financiación de Serie A para com
# --------------------------------------------------
# Nombre: Clinicos. Claim: "Tu clínica al alcance de un click".
# Idea de negocio: Clinicos será una plataforma SaaS B2C innovadora para clínicas
# de Madrid. Ofreceremos a los usuarios una solución única, para reservar citas,
# realizar pagos en línea, recibir notificaciones y recibir información sobre sus
# tratamientos. Además, ofreceremos a los profesionales una herramienta para la
# gestión de sus pacientes.
# Plataforma: Estamos desarrollando Clinicos con la última tecnología web y móvil,
# para garantizar una experiencia de usuario premium. Estamos trabajando para
# lanzar la primera versión de la plataforma en tres meses.
# Marketing y Ventas: Nuestra plataforma se dirige a clínicas y profesionales de
# salud de Madrid. Estamos desarrollando una estrategia de marketing en línea y
# offline para lograr una alta visibilidad y una base de usuarios activos.
# Esperamos facturar 1 millón de euros el primer año.
# Equipo: El equipo emprendedor de Clinicos está formado por un equipo
# multidisciplinar de expertos en desarrollo web, diseño, marketing y ventas.
# Financiación: Estamos buscando una ronda de seed capital de 250.000 euros para
# desarrollar el producto. Una vez que hayamos lanzado la primera versión,
# buscaremos una ronda de series A de 1 millón de euros para empezar a vender
# nuestro producto.
# --------------------------------------------------
# Nombre:  Clinik - Tu salud, en las mejores manos.
# Claim: Tu salud, en un clic.
# Idea de negocio: Un software SaaS B2C para la gestión y administración de la
# salud, que ofrece una experiencia única para los usuarios y profesionales
# sanitarios, proporcionando a los pacientes información, servicios y precios.
# Ofreceremos una plataforma segura para el seguimiento de la salud, y la
# posibilidad de hacer citas, recibir recomendaciones personalizadas, y servicios
# de teleasistencia.
# Plataforma: Usaremos tecnologías de software modernas y avanzadas para
# desarrollar una plataforma escalable y sostenible, con una interfaz intuitiva.
# Estimamos que llevará entre seis y nueve meses llegar al primer producto
# vendible.
# Marketing y Ventas: Nuestro público objetivo son personas en Londres y el Reino
# Unido, que busquen una solución innovadora para la gestión de la salud.
# Utilizaremos estrategias de marketing digital para llegar a ellos, y esperamos
# facturar alrededor de 500.000 libras al año.
# Equipo: El equipo emprendedor está formado por profesionales experimentados en
# el ámbito de la salud digital y la tecnología.
# Financiación: Necesitaremos una ronda de seed capital para desarrollar el
# producto, y una ronda de series A para empezar a vender.
# --------------------------------------------------
# Nombre: GetSelect. Claim: “Tu inmueble, tu elección”.
# Idea de negocio: GetSelect es un software SaaS B2C innovador en el sector
# inmobiliario, que facilita la compra y venta de inmuebles en Madrid. Nuestro
# software ofrece una plataforma con información clara y detallada sobre los
# inmuebles, con herramientas para ordenar y filtrar por características,
# ubicación, precio, etc. Nuestra plataforma permite una búsqueda ágil y clara de
# inmuebles, y una gestión sencilla de la compra.
# Plataforma: Desarrollaremos nuestro software con tecnología de última
# generación, para asegurar una experiencia de usuario óptima. Estimamos un tiempo
# de desarrollo de 6 meses para tener el primer producto vendible.
# Marketing y Ventas: Nuestro objetivo es ofrecer nuestra plataforma a
# propietarios y compradores de inmuebles, principalmente en Madrid. Utilizaremos
# estrategias de marketing online para llegar a nuestros potenciales clientes.
# Esperamos facturar el primer año unos 200.000€.
# Equipo: Nuestro equipo emprendedor está formado por especialistas en software y
# marketing digital, y un profesional del sector inmobiliario.
# Financiación: Necesitaremos una ronda de seed capital para desarrollar el
# producto, y una de series A para empezar a vender.
# --------------------------------------------------
# Nombre y Claim: HouseFinder.uk - Descubre tu hogar perfecto.
# Idea de Negocio: HouseFinder.uk es una plataforma SaaS B2C que conecta a los
# compradores de vivienda con los mejores inmobiliarias y agentes de Londres. El
# software proporciona una búsqueda avanzada de inmuebles, ofreciendo la mejor
# selección y una experiencia de compra sostenible.
# Plataforma: Utilizaremos una plataforma basada en la nube para proporcionar una
# experiencia de usuario intuitiva y segura. Nuestra tecnología de vanguardia nos
# permitirá lanzar el primer producto en menos de 12 meses.
# Marketing y Ventas: Nuestro público objetivo son aquellos que buscan comprar o
# alquilar una vivienda en Londres. Utilizaremos una combinación de publicidad
# digital, promoción de contenidos y relaciones con los medios para llegar al
# público. Esperamos facturar 2 millones de libras esterlinas el primer año.
# Equipo: Nuestro equipo está formado por un grupo de emprendedores entusiastas
# con una amplia experiencia en tecnología, relaciones con los medios, marketing y
# ventas.
# Financiación: Necesitaremos una ronda de capital semilla para desarrollar el
# producto y una ronda de Serie A para empezar a vender. Estamos buscando
# inversores que reconozcan el valor de nuestro producto y compartan nuestra
# visión.
# --------------------------------------------------
