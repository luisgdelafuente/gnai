# %%
# Creating some synthetic data for fine-tuning 
# We are going to create serveral characters for video games in here: 

import os
import openai
import pandas as pd

# Set your OpenAI API key
openai.api_key = os.getenv("OPENAI_API_KEY")

# Define input values
negocios = ['subscripción', 'publicidad'] 
industrias = ['clinicas', 'inmobiliaria']
ubicaciones = ['madrid','londres'] 

# Create an empty list to store results
results = []

# Loop through input values
record_number = 1
for negocio in negocios:
    for industria in industrias:
        for ubicacion in ubicaciones:
            # Define the prompt with placeholders
            prompt = f"Escribe en un máximo de 25 palabras una idea de negocio original e innovadora, con un modelo {negocio}, en el sector de {industria}, ubicada en {ubicacion} siguiendo estas instrucciones por líneas: Nombre y claim para la startup: corto y catchy, Idea de negocio: describe el valor añadido concreto y la diferenciación del software, Plataforma: Describe qué tecnología vas a usar, y el tiempo que llevará llegar al primero producto vendible, Marketing y Ventas: Indica a quien se dirige, qué estrategias de marketing usarás para llegar a ese público y cuanto esperas facturar el primer año, Equipo: Describe al equipo emprendedor, Financiación: Escribe brevemente las rondas que vas a necesitar de seed capital para desarrollar el producto, y series A para empezar a vender. Escribe como el propio emprendedor, con todo apasionado y profesional. "

            # Generate the response using OpenAI's GPT-3 model
            response = openai.Completion.create(
                model="text-davinci-003",
                prompt=prompt,
                temperature=0.7,  # Adjust temperature for response creativity
                max_tokens=500,  
                frequency_penalty=0,
                n=1,  # Generate a single response
                stop=None,  # Let the model determine when to stop
            )

            # Extract and store the response text
            response_text = response.choices[0].text.strip()

            # Create a subprompt string
            subprompt = f"{negocio}, {industria}, {ubicacion}"

            # Store the results in a dictionary
            result = {
                'record number': record_number,
                'negocio': negocio,
                'industria': industria,
                'ubicacion': ubicacion,
                'prompt': prompt,
                'subprompt': subprompt,
                'response': response_text
            }

            results.append(result)

            # Increment the record number
            record_number += 1

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
df.to_csv("saas.csv", index=False)

# %%
import textwrap

# Assuming you have a DataFrame named 'df' with a column named 'response'
for paragraph in df['response']:
    paragraphs = paragraph.split('\n')  # Split by line breaks
    for p in paragraphs:
        wrapped_paragraphs = textwrap.wrap(p, width=80)  # Adjust the width as needed
        for wrapped_p in wrapped_paragraphs:
            print(wrapped_p)
    print('-' * 50)  # Add a line break separator
# Out:
# Nombre y claim para la startup: Clinicas Subscripción: "Tu salud a tu ritmo".
# Idea de negocio: Ofrecemos servicios de clínicas médicas ilimitados a una tarifa
# fija mensual. Nuestro modelo de subscripción permite a los pacientes tener una
# asistencia médica rápida y segura, con los mejores profesionales en Madrid.
# Plataforma: Usaremos la tecnología más avanzada para ofrecer una solución fácil
# de usar al paciente, con una interfaz intuitiva. Estaremos listos para el primer
# producto vendible en aproximadamente 6 meses.
# Marketing y Ventas: Nuestro producto está dirigido a personas entre 25 y 50 años
# de edad, ya sean trabajadores, estudiantes o profesionales. Usaremos estrategias
# de marketing digital para llegar a nuestro público objetivo y esperamos facturar
# unos 150.000€ el primer año.
# Equipo: Somos un equipo de 4 profesionales con experiencia en el sector de la
# salud, con una gran motivación y una pasión por ayudar a las personas.
# Financiación: Necesitaremos una ronda de seed capital para desarrollar el
# producto y una serie A para empezar a vender.
# --------------------------------------------------
# Nombre y claim para la startup: HealthPlus: Tu salud, nuestra prioridad.
# Idea de negocio: HealthPlus es una clínica con modelo de subscripción para el
# área de salud en Londres. Ofrecemos un servicio único de atención médica
# personalizada, con acceso a citas de la manera más rápida y eficiente.
# Plataforma: Usaremos una plataforma web segura, construida con la última
# tecnología, para garantizar una experiencia fluida para nuestros usuarios.
# Esperamos desarrollar el primer producto en un plazo de 6 meses.
# Marketing y Ventas: Nuestro objetivo es llegar a profesionales de alto nivel,
# con un presupuesto para salud y un estilo de vida activo. Usaremos una
# combinación de publicidad digital, redes sociales, relaciones públicas y
# estrategias de contenido para aumentar nuestra visibilidad. Esperamos facturar
# un mínimo de 500.000 libras el primer año.
# Equipo: Nuestro equipo está formado por 8 personas, con una amplia experiencia y
# conocimientos en el sector de la salud.
# Financiación: Necesitamos una ronda de inversión de semilla de 200.000 libras
# para el desarrollo de nuestro producto, y una segunda ronda de financiación de
# series A de 500.000 libras para empezar a vender.
# --------------------------------------------------
# Nombre y claim para la startup: InmoFlex, tu inmueble al alcance de la mano.
# Idea de negocio: Ofrecer un servicio de plataforma de alquiler de inmuebles por
# suscripción, con el fin de ahorrar tiempo en la búsqueda de inmuebles.
# Plataforma: Usaremos React Native para desarrollar una aplicación móvil, así
# como una web de contenido para la gestión de usuarios y reservas. El proyecto
# llevaría unas 8 semanas desde el inicio hasta el lanzamiento. Marketing y
# Ventas: Nos dirigiremos a personas entre 25-35 años, con un alto poder
# adquisitivo, a través de campañas publicitarias online, redes sociales, y
# colaboraciones con empresas. Esperamos facturar más de 100.000€ el primer año.
# Equipo: Contamos con un equipo de profesionales apasionados por el
# emprendimiento, con experiencia en sectores relacionados. Financiación:
# Necesitamos una ronda de seed capital para desarrollar nuestro producto, así
# como una serie A para empezar a vender.
# --------------------------------------------------
# Nombre y claim para la startup: "LiveLux: Viviendo el lujo con estilo".
# Idea de negocio: Ofrecemos la experiencia de vivir en las mejores zonas de
# Londres sin tener que comprar una propiedad. Ofrecemos una plataforma única con
# un modelo de subscripción que permite a los usuarios alquilar una variedad de
# propiedades de lujo durante un período de tiempo.
# Plataforma: Usamos tecnología de vanguardia para crear una plataforma web segura
# y fácil de usar, que se lanzará en un plazo de 6 meses.
# Marketing y Ventas: Dirigido a profesionales de 30 a 40 años en busca de una
# mejora de calidad de vida, nuestra estrategia de marketing se basará en una
# presencia fuerte en los medios de comunicación, publicidad digital y un programa
# de lealtad. Esperamos facturar $50,000 el primer año.
# Equipo: El equipo está formado por expertos en el sector inmobiliario,
# desarrollo de software y marketing digital.
# Financiación: Necesitaremos una ronda de semilla de $500,000 para el desarrollo
# del producto y una ronda de Serie A de $2,000,000 para empezar a vender.
# --------------------------------------------------
# Clinic-Up: "Tu salud, tu bienestar".
# Idea de negocio: Clinic-Up es una plataforma digital de clínicas de salud y
# bienestar en Madrid, con una tecnología avanzada para ofrecer a los usuarios una
# experiencia digital única. Clinic-Up ofrece una experiencia de atención médica
# personalizada, la evaluación médica en línea, la reserva de citas y el
# seguimiento de los resultados de la salud y el bienestar de los usuarios.
# Plataforma: Clinic-Up está construido con una tecnología de software de
# vanguardia, con un enfoque centrado en los usuarios. Nuestra plataforma estará
# lista para el lanzamiento en menos de 6 meses.
# Marketing y ventas: Nuestro objetivo es llegar a todos los usuarios de Madrid
# que buscan una experiencia de atención médica de calidad. Nuestras estrategias
# de marketing incluyen el uso de publicidad digital, SEO, anuncios en redes
# sociales y campañas de email. Esperamos facturar más de 2 millones de euros el
# primer año.
# Equipo: Nuestro equipo está compuesto por profesionales de la salud, expertos en
# tecnología y profesionales de marketing, todos con una amplia experiencia en el
# sector.
# Financiación: Necesitamos una ronda de capital semilla para desarrollar el
# producto y una serie A para empezar a vender. Estamos buscando entre $1M y $2M
# en capital semilla, y entre $5M y $10M en la Serie A.
# --------------------------------------------------
# Nombre y claim: Healthify - "Tu salud, mejorada digitalmente".
# Idea de negocio: Healthify es una plataforma digital que conecta a los clínicos
# con sus pacientes para mejorar la calidad de vida a través de una atención
# médica remota y segura.
# Plataforma: Utilizaremos la tecnología blockchain para garantizar la seguridad y
# privacidad de los datos de los pacientes, y la inteligencia artificial para
# optimizar el uso de los recursos de los clínicos. Estimamos que llevará 6 meses
# lanzar el primer producto vendible.
# Marketing y Ventas: Nuestro público objetivo serán los clínicos y los
# profesionales de la salud de Londres. Utilizaremos el marketing digital para
# promocionar nuestra plataforma y esperamos facturar alrededor de un millón de
# libras en el primer año.
# Equipo: Somos un equipo de profesionales de la salud, con experiencia en
# desarrollo de software y tecnología médica.
# Financiación: Necesitamos una ronda de seed capital para desarrollar el producto
# y una ronda de series A para comenzar la venta.
# --------------------------------------------------
# Nombre y Claim: InmoTec - "Tu hogar, al alcance de un click".
# Idea de Negocio: InmoTec ofrecerá una plataforma de inmobiliaria innovadora y
# digital, que conectará a propietarios de viviendas con sus futuros inquilinos.
# Facilitando la búsqueda de viviendas a través de nuestro software, ofreceremos
# un servicio eficaz y personalizado, ahorrando tiempo y esfuerzo a los usuarios.
# Plataforma: Usaremos la última tecnología para crear una plataforma amigable
# para el usuario, con una interfaz intuitiva y con información precisa. Estimamos
# que el desarrollo del software tome entre 3 y 5 meses.
# Marketing y Ventas: Nuestro público objetivo será inquilinos y propietarios de
# viviendas, tanto en Madrid como en el resto de España. Utilizaremos estrategias
# de marketing digital (redes sociales, publicidad online, campañas publicitarias)
# para llegar a nuestro público. Esperamos facturar entre 1 y 2 millones de euros
# el primer año.
# Equipo: El equipo emprendedor de InmoTec está compuesto por 4 miembros con
# experiencia en el sector inmobiliario y tecnología, con el objetivo de ofrecer
# una solución única en el mercado.
# Financiación: Para desarrollar el producto necesitaremos una ronda de Seed
# capital, y posteriormente una Serie A para empezar a vender.
# --------------------------------------------------
# Nombre y claim para la startup: HomeFinder, encuentra tu hogar.
# Idea de negocio: Ofrecemos un software de inmobiliaria que facilita a los
# usuarios encontrar la casa de sus sueños con una experiencia de usuario única.
# Nuestra plataforma se basa en inteligencia artificial para ofrecer a los
# usuarios los anuncios más relevantes según sus criterios de búsqueda.
# Plataforma: Utilizamos la última tecnología para conectar clientes y anunciantes
# en nuestro software. Utilizamos el lenguaje de programación más moderno y nos
# llevará aproximadamente 6 meses para tener el producto en línea y listo para ser
# vendido.
# Marketing y Ventas: Nuestro público objetivo son personas de 25 a 40 años que
# buscan una casa en Londres. Utilizaremos estrategias de marketing en línea para
# llegar a nuestro público. Esperamos facturar aproximadamente 1 millón de libras
# esterlinas en el primer año.
# Equipo: Estamos compuestos por un equipo emprendedor de programadores,
# desarrolladores web y expertos en marketing.
# Financiación: Necesitamos una ronda de capital semilla para el desarrollo del
# producto y una serie A para iniciar la venta.
# --------------------------------------------------

# %%
# Now we are going to increase the parameters to 5

import os
import openai
import pandas as pd

# Set your OpenAI API key
openai.api_key = os.getenv("OPENAI_API_KEY")

# Define input values
industries = ['clean energy', 'blockchain', 'health']
models = ['subscription', 'advertising', 'e-commerce']
fundings = ['bootstrapped', 'pre-seed', 'seed']
locations = ['london', 'berlin', 'barcelona']
targets = ['boomers', 'generation X', 'millennials']

# Create an empty list to store results
results = []

# Loop through input values
record_number = 1
for industry in industries:
    for model in models:
        for funding in fundings:
            for location in locations:
                for target in targets:
                    # Define the prompt
                    prompt = f"Create an original and innovative business idea for a startup that targets {target} in the {industry} industry. The business model will be {model}, based in {location}, and funded through {funding}. Provide a short and catchy name for the startup as well as a 1-paragraph business idea."

                    # Generate the response using OpenAI's GPT-3 model
                    response = openai.Completion.create(
                        model="text-davinci-003",
                        prompt=prompt,
                        temperature=0.7,
                        max_tokens=500,
                        frequency_penalty=0,
                        n=1,
                        stop=None,
                    )

                    # Extract and store the response text
                    response_text = response.choices[0].text.strip()

                    # Create a subprompt string
                    subprompt = f"{industry}, {model}, {funding}, {location}, {target}"

                    # Store the results in a dictionary
                    result = {
                        'record number': record_number,
                        'industry': industry,
                        'model': model,
                        'funding': funding,
                        'location': location,
                        'target': target,
                        'prompt': prompt,
                        'subprompt': subprompt,
                        'response': response_text
                    }

                    results.append(result)

                    # Increment the record number
                    record_number += 1

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
df.to_csv("startup_ideas.csv", index=False)
