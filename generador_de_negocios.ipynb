# %%
# Creating some synthetic data for fine-tuning 
# We are going to create serveral characters for video games in here: 

import os
import openai
import pandas as pd

# Set your OpenAI API key
openai.api_key = os.getenv("OPENAI_API_KEY")

# Define input values
negocios = ['B2B', 'B2C'] 
industrias = ['clinicas', 'inmobiliaria']
ubicaciones = ['madrid','londres'] 

# Create an empty list to store results
results = []

# Loop through input values
record_number = 1
for negocio in negocios:
    for industria in industrias:
        for ubicacion in ubicaciones:
            # Define the prompt with placeholders
            prompt = f"Eres un analista con muchos años de experiencia en software y sistemas SaaS. Crea una idea de negocio para una startup innovadora que desarrolla un SaaS {negocio} en el sector de {industria}, y que está ubicada en {ubicacion} siguiendo estas instrucciones: detalla a quién se dirige, la diferenciación, modelo de negocio, equipo emprendedor, procura utilizar un tono como si fueras el emprendedor, y utiliza 300 palabras en total."

            # Generate the response using OpenAI's GPT-3 model
            response = openai.Completion.create(
                model="text-davinci-003",
                prompt=prompt,
                temperature=0.7,  # Adjust temperature for response creativity
                max_tokens=500,  
                n=1,  # Generate a single response
                stop=None,  # Let the model determine when to stop
            )

            # Extract and store the response text
            response_text = response.choices[0].text.strip()

            # Create a subprompt string
            subprompt = f"{negocio}, {industria}, {ubicacion}"

            # Store the results in a dictionary
            result = {
                'record number': record_number,
                'negocio': negocio,
                'industria': industria,
                'ubicacion': ubicacion,
                'prompt': prompt,
                'subprompt': subprompt,
                'response': response_text
            }

            results.append(result)

            # Increment the record number
            record_number += 1

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
df.to_csv("saas.csv", index=False)

# %%
import textwrap

# Assuming you have a DataFrame named 'df' with a column named 'response'
for paragraph in df['response']:
    paragraphs = paragraph.split('\n')  # Split by line breaks
    for p in paragraphs:
        wrapped_paragraphs = textwrap.wrap(p, width=80)  # Adjust the width as needed
        for wrapped_p in wrapped_paragraphs:
            print(wrapped_p)
    print('-' * 50)  # Add a line break separator
# Out:
# Mi startup innovadora se llama ClinicsCloud y se dirige a clínicas y centros
# médicos en la ciudad de Madrid. ClinicsCloud es una plataforma de software Saas
# (Software as a Service) que ofrece soluciones innovadoras para optimizar la
# gestión y el flujo de trabajo de las clínicas, mejorando la productividad y la
# eficiencia operativa.
# Nuestra solución está diseñada para reducir la complejidad de la gestión
# clínica, proporcionando herramientas de colaboración en línea, servicios de
# seguimiento de pacientes, escaneo de documentos, procesamiento de facturación y
# otros servicios. Estas herramientas son fáciles de usar y están diseñadas para
# agilizar la administración de la clínica.
# Nuestro modelo de negocio consiste en ofrecer una solución de suscripción
# mensual para nuestras clínicas clientes, ofreciendo descuentos por compras en
# grupo. Nuestros precios estarán entre los más bajos del mercado y ofreceremos
# una prueba gratuita de 10 días para que los clientes puedan probar nuestro
# servicio.
# Nuestro equipo de emprendedores está compuesto por profesionales con experiencia
# en servicios SaaS, tecnología, gestión de clínicas y marketing. Tenemos una
# amplia experiencia en el desarrollo de software y la gestión de clínicas, lo que
# nos permite ofrecer una solución verdaderamente innovadora y única.
# Nuestra solución se diferencia de la competencia por su facilidad de uso, su
# precio competitivo y su alto nivel de seguridad. Estamos seguros
# --------------------------------------------------
# Mi nueva empresa, Clinicas SaaS es una empresa de desarrollo de software B2B
# ubicada en Londres, que se enfoca en el sector de las clinicas. Nuestro enfoque
# es proporcionar una solución de software SaaS personalizada que ofrezca una
# mejor experiencia a los usuarios de clinicas. Estamos enfocados en proporcionar
# soluciones de software flexibles para satisfacer las necesidades de nuestros
# clientes.
# Nuestro software se especializa en ofrecer una mejor administración de los
# registros de pacientes, mejorar la eficiencia en la administración de los
# procesos clínicos, automatizar el flujo de trabajo en la clínica y mejorar la
# comunicación con los pacientes. Nuestro software también compilará datos y
# tendencias para ofrecer una mejor comprensión del sistema clínico.
# Nuestro equipo emprendedor está compuesto por profesionales con amplia
# experiencia en el desarrollo de software y en el sector de clinicas. Estamos
# comprometidos con la innovación y la mejora constante de nuestro software para
# satisfacer las necesidades cambiantes de nuestros clientes.
# Nuestro modelo de negocio es un modelo de suscripción que ofrece a nuestros
# clientes una solución flexible de software SaaS. Nuestra solución se ajusta a la
# medida de nuestros clientes, permitiendo una personalización a medida que
# aumenta la eficiencia en la administración de la clínica.
# Nuestra solución se dirige a clinicas pequeñas, medianas y grandes, tanto
# públicas como privadas, en el Reino Unido y en todo el mundo. Nuestra plataform
# --------------------------------------------------
# Como emprendedor, mi objetivo es ofrecer un servicio SaaS B2B en el sector de la
# inmobiliaria para proporcionar a nuestros clientes una solución innovadora que
# les permita optimizar sus procesos. Nuestra startup está ubicada en Madrid y
# está dirigida a inmobiliarias, agentes inmobiliarios, gestores de propiedades,
# desarrolladores inmobiliarios, inversores inmobiliarios, compradores,
# vendedores, inquilinos y propietarios.
# Nuestro objetivo es proporcionar una solución de software única que permita a
# nuestros clientes gestionar de forma segura y eficiente sus transacciones
# inmobiliarias. Nuestra solución será fácil de usar, segura y escalable. Además,
# proporcionaremos herramientas para optimizar los flujos de trabajo de los
# usuarios y proporcionarles información actualizada sobre el mercado
# inmobiliario.
# Nuestro modelo de negocio se basará en la suscripción a nuestro servicio, con
# tarifas mensuales y anuales. Contaremos con un equipo de emprendedores
# experimentados que asumirán el desarrollo, la implementación y la gestión de
# nuestra solución. Estamos comprometidos con la innovación y la excelencia en el
# servicio al cliente.
# Nuestra solución se distinguirá de la competencia al ofrecer una solución
# altamente personalizada para satisfacer las necesidades específicas de nuestros
# clientes. Nuestras herramientas ofrecerán información actualizada sobre el
# mercado inmobiliario para mantener a nuestros clientes al día de las tendencias
# del sector. Nuestra solución se desarrollará de forma escalable para satisf
# --------------------------------------------------
# Mi nombre es George y soy el emprendedor de la nueva startup innovadora que
# desarrolla un SaaS B2B en el sector de la inmobiliaria ubicada en Londres.
# Estamos enfocados en ofrecer soluciones innovadoras que mejoren la gestión
# eficiente y la calidad de los servicios de inmobiliarias, corredores y agentes
# inmobiliarios.
# Nuestra diferenciación radica en que somos una empresa de software de propiedad
# absoluta, no una empresa de terceros. Esto nos permite desarrollar una solución
# única para los clientes que se adapte a sus necesidades específicas. Estamos
# comprometidos con el desarrollo de soluciones de software de alta calidad,
# seguras y fáciles de usar, con el objetivo de mejorar la eficiencia y la
# productividad de nuestros clientes.
# Nuestro modelo de negocio se basa en ofrecer un servicio premium, con una
# suscripción mensual para acceder a nuestro software. Ofrecemos diferentes planes
# de suscripción con servicios y funciones adicionales a precios diferentes para
# satisfacer las necesidades de nuestros clientes. Nuestra solución se puede
# personalizar para satisfacer las necesidades individuales de cada cliente.
# Nuestro equipo emprendedor está compuesto por profesionales de la industria de
# la tecnología, la inmobiliaria y el marketing. Tenemos una visión clara de
# nuestros objetivos y estamos comprometidos a ofrecer soluciones innovadoras y de
# calidad a nuestros clientes.
# Estamos comprometidos a mejorar la productividad, la eficiencia y el valor que
# ofrec
# --------------------------------------------------
# Mi nombre es Andrés y soy emprendedor en Madrid. Estoy desarrollando una startup
# innovadora, centrada en el sector de las clínicas. Estoy desarrollando un SaaS
# B2C para ofrecer servicios innovadores a clínicas privadas y públicas. Esta
# plataforma se basará en la tecnología SaaS, lo que significa que los usuarios
# tendrán acceso a los servicios sin necesidad de instalar y configurar hardware.
# Esta startup se dirige principalmente a clínicas privadas, quienes podrán
# acceder a una amplia gama de servicios para optimizar el trabajo de su equipo.
# Estos servicios incluyen una plataforma de pruebas de diagnóstico, un sistema de
# gestión de citas para la agenda del médico y un software de gestión de
# documentación para la recopilación de información. Esto permitirá a los
# profesionales de la salud mejorar la eficiencia en el trabajo y ofrecer un mejor
# servicio a sus pacientes.
# La diferenciación de esta startup se basa en la innovación tecnológica, la
# facilidad de uso y la seguridad de la información. Esta startup usará un modelo
# de suscripción para permitir a los usuarios pagar por los servicios de la
# plataforma. Esto significa que los usuarios pagaran una cantidad mensual, la
# cual se recalculará en base a la cantidad de servicios que sean utilizados.
# Por otro lado, el equipo emprendedor se compone de profesionales altamente
# cualificados en el desarrollo de software y sistemas SaaS. También contaré con
# un equipo de profesionales de marketing digital para promover la plataforma a
# trav
# --------------------------------------------------
# Mi nombre es Alex y estoy fundando una nueva startup SaaS B2C en el sector de
# clinicas en Londres. Estoy convencido de que, con el apoyo de un equipo
# emprendedor dedicado, podemos desarrollar una plataforma innovadora que mejore
# la experiencia de los usuarios y abra nuevas oportunidades de negocio para las
# clinicas.
# Nuestra plataforma se dirige directamente a los usuarios particulares que buscan
# una clínica para recibir tratamiento. Ofrecemos una experiencia más conveniente
# y una solución integral para la búsqueda de servicios médicos. Los usuarios
# pueden encontrar todos los servicios médicos que necesitan, desde el diagnóstico
# hasta el tratamiento, todo a través de nuestra plataforma.
# Nuestra plataforma se destacará de la competencia al ofrecer una solución
# innovadora que mejore la experiencia del usuario. Nuestros usuarios podrán
# reservar citas con facilidad, navegar por una amplia gama de servicios, obtener
# recomendaciones personalizadas y hacer seguimiento a sus servicios desde nuestra
# plataforma. También ofrecemos un sistema de pago seguro para garantizar la
# satisfacción de los usuarios.
# Nuestro modelo de negocio se basa en la generación de ingresos a través de
# comisiones por cada reserva de citas realizada a través de nuestra plataforma,
# así como también por la publicidad de otras empresas del sector. Esto nos
# permitirá generar ingresos a medida que nuestra base de usuarios crece y nos
# ayudará a proporcionar una pl
# --------------------------------------------------
# Mi nombre es Carlos y soy el fundador de una startup de Software como Servicio
# (SaaS) B2C en el sector de bienes raíces en Madrid. Mi equipo de emprendedores y
# yo estamos determinados a ofrecer una plataforma enfocada en el mercado de
# inmobiliaria, que ofrezca una experiencia única a los usuarios.
# Nuestro objetivo es ayudar a los compradores de viviendas a encontrar la
# propiedad correcta para ellos, mientras se ahorran tiempo y dinero. Estamos
# dirigidos a aquellos que están buscando comprar una vivienda en Madrid, ya sea
# de forma rápida o a largo plazo.
# Nuestra plataforma ofrecerá una variedad de herramientas que facilitarán la
# búsqueda de viviendas, así como otros servicios que ayudarán a los compradores a
# tomar decisiones informadas. Estas herramientas incluyen una cámara de realidad
# aumentada para explorar dentro de las viviendas, una función de búsqueda de
# viviendas que permite a los usuarios encontrar la propiedad perfecta para ellos,
# así como herramientas de comparación de precios para ayudarles a obtener el
# mejor trato posible.
# Además, nuestra plataforma ofrecerá una variedad de recursos y consejos a los
# compradores de viviendas. Estos incluyen consejos sobre cómo prepararse para
# comprar una vivienda, consejos sobre cómo elegir el mejor prestamista de
# hipotecas, y consejos sobre cómo ahorrar dinero al comprar una vivienda.
# Nuestro modelo de negocio se basa en la suscripción
# --------------------------------------------------
# Soy un emprendedor con muchos años de experiencia en el sector de software y
# sistemas SaaS, y estoy comprometido con la innovación y el cambio. Estoy creando
# una startup en Londres que desarrollará un SaaS B2C en el sector inmobiliario.
# Estoy comprometido a ayudar a los propietarios y compradores a comprar y vender
# propiedades de manera más eficiente, rápida y segura.
# Mi startup se dirigirá principalmente a propietarios y compradores de
# propiedades en Londres. Nuestro objetivo es ofrecer un servicio de clase mundial
# que se destaque de otras empresas de inmobiliaria al proporcionar a los usuarios
# una plataforma de gestión de propiedades fácil de usar y segura. En comparación
# con otros sistemas, nuestro SaaS ofrecerá una solución única que ayudará a los
# usuarios a realizar transacciones de manera rápida, eficiente y segura.
# Nuestro modelo de negocio se basará en una suscripción mensual para usuarios
# tanto individuales como comerciales. Esto nos permitirá generar ingresos
# recurrentes, así como también ofrecer precios competitivos a los usuarios.
# Utilizaremos nuestras herramientas de marketing digital para llegar a una
# audiencia más amplia.
# Nuestro equipo emprendedor estará compuesto por profesionales altamente
# capacitados en el sector de la inmobiliaria, el software y los sistemas SaaS.
# Compartiremos nuestra experiencia y conocimiento para asegurar que nuestra
# solución sea una de las mejores del mercado.
# Tengo la intención
# --------------------------------------------------
