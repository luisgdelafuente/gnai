# %%
# Creating some synthetic data for fine-tuning 
# We are going to create serveral characters for video games in here: 

import os
import openai
import pandas as pd

# Set your OpenAI API key
openai.api_key = os.getenv("OPENAI_API_KEY")

# Define input values
negocios = ['subscripción', 'publicidad' , 'e-commerce' , 'freemium' , 'pay-per-use'] 
industrias = ['clinicas', 'inmobiliaria']
ubicaciones = ['madrid','londres'] 

# Create an empty list to store results
results = []

# Loop through input values
record_number = 1
for negocio in negocios:
    for industria in industrias:
        for ubicacion in ubicaciones:
            # Define the prompt with placeholders
            prompt = f"Escribe en un máximo de 25 palabras una idea de negocio original e innovadora, con un modelo {negocio}, en el sector de {industria}, ubicada en {ubicacion} siguiendo estas instrucciones por líneas: Nombre y claim para la startup: corto y catchy, Idea de negocio: describe el valor añadido concreto y la diferenciación del software, Plataforma: Describe qué tecnología vas a usar, y el tiempo que llevará llegar al primero producto vendible, Marketing y Ventas: Indica a quien se dirige, qué estrategias de marketing usarás para llegar a ese público y cuanto esperas facturar el primer año, Equipo: Describe al equipo emprendedor, Financiación: Escribe brevemente las rondas que vas a necesitar de seed capital para desarrollar el producto, y series A para empezar a vender. Escribe como el propio emprendedor, con todo apasionado y profesional. "

            # Generate the response using OpenAI's GPT-3 model
            response = openai.Completion.create(
                model="text-davinci-003",
                prompt=prompt,
                temperature=0.7,  # Adjust temperature for response creativity
                max_tokens=500,  
                frequency_penalty=0,
                n=1,  # Generate a single response
                stop=None,  # Let the model determine when to stop
            )

            # Extract and store the response text
            response_text = response.choices[0].text.strip()

            # Create a subprompt string
            subprompt = f"{negocio}, {industria}, {ubicacion}"

            # Store the results in a dictionary
            result = {
                'record number': record_number,
                'negocio': negocio,
                'industria': industria,
                'ubicacion': ubicacion,
                'prompt': prompt,
                'subprompt': subprompt,
                'response': response_text
            }

            results.append(result)

            # Increment the record number
            record_number += 1

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
df.to_csv("saas.csv", index=False)

# %%
import textwrap

# Assuming you have a DataFrame named 'df' with a column named 'response'
for paragraph in df['response']:
    paragraphs = paragraph.split('\n')  # Split by line breaks
    for p in paragraphs:
        wrapped_paragraphs = textwrap.wrap(p, width=80)  # Adjust the width as needed
        for wrapped_p in wrapped_paragraphs:
            print(wrapped_p)
    print('-' * 50)  # Add a line break separator
# Out:
# Nombre y claim para la startup: CareClinics: Tu salud a un click.
# Idea de negocio: Ofrecemos una plataforma digital para la gestión de citas
# médicas, con la intención de optimizar el trabajo de las clínicas en Madrid.
# Esto se logra gracias a nuestras herramientas de automatización, que permiten a
# los pacientes solicitar y programar citas médicas de forma rápida.
# Plataforma: Utilizaremos una mezcla de tecnologías web y de movilidad para crear
# una plataforma intuitiva. Nuestro objetivo es alcanzar el primer producto
# vendible en un plazo de tres meses.
# Marketing y Ventas: Nuestro público objetivo son clínicas en Madrid.
# Utilizaremos una combinación de publicidad en línea y campañas de marketing
# tradicional para llegar a ellas. Esperamos facturar un millón de euros al año.
# Equipo: Estamos compuestos por un equipo de desarrolladores, diseñadores,
# ingenieros y expertos en marketing.
# Financiación: Necesitamos una ronda de seed capital para desarrollar nuestro
# producto y una ronda de series A para comenzar a vender.
# --------------------------------------------------
# Nombre y claim: KeepCare - Tu salud, a tu alcance.
# Idea de negocio: KeepCare ofrecerá una plataforma en línea de subscripción que
# permitirá a los usuarios acceder y reservar citas para la atención médica en
# clínicas de Londres. El software permitirá a los usuarios acceder a información
# sobre los tratamientos, consultar estadísticas y obtener recomendaciones de
# especialistas.
# Plataforma: Utilizaremos tecnologías web, inteligencia artificial para
# proporcionar recomendaciones y una interfaz intuitiva para recibir reservas de
# citas. Estimamos que el primer producto vendible estará listo en 6 meses.
# Marketing y Ventas: Nuestro público objetivo son profesionales en Londres entre
# 25-45 años, llegaremos a ellos a través de campañas de publicidad online, y
# esperamos facturar 2 millones de libras el primer año.
# Equipo: El equipo emprendedor está compuesto por 5 personas con amplia
# experiencia en el sector de la tecnología y la medicina.
# Financiación: Necesitaremos 2 rondas de seed capital para desarrollar el
# producto, y una ronda de series A para empezar a venderlo.
# --------------------------------------------------
# Nombre y claim: Homely, tu hogar siempre contigo.
# Idea de negocio: Homely ofrece un servicio de subscripción a inmuebles en Madrid
# con la facilidad de poder trasladarse entre ellos cada mes sin la molestia de
# tener que cambiar de contrato o de trabajo.
# Plataforma: Usaremos una plataforma de software propia para gestionar la
# subscripción, con una interfaz sencilla para los usuarios, y una aplicación
# móvil para una mejor experiencia. Estimamos que desarrollar el producto llevará
# unos 6-8 meses.
# Marketing y Ventas: Estamos dirigidos a los millennials, aquellos que buscan
# flexibilidad y movilidad en su vida. Usaremos estrategias de marketing digital,
# publicidad en redes sociales, y campañas de email marketing. Esperamos facturar
# al menos 1 millón de euros el primer año.
# Equipo: Somos un equipo de emprendedores con experiencia en el sector
# inmobiliario, y en el desarrollo de software.
# Financiación: Necesitamos una ronda de seed capital de 500.000 € para el
# desarrollo del software, y una ronda de Series A para empezar a vender el
# producto.
# --------------------------------------------------
# Nombre y claim: RentMe, "Haz de tu hogar un lugar más cómodo".
# Idea de negocio: RentMe es una plataforma de inmobiliaria en línea que conecta a
# inquilinos y propietarios en Londres. Ofrece soluciones de alquiler asequibles,
# seguras y cómodas para todos los usuarios.
# Plataforma: RentMe se construirá con tecnología de última generación. Esta
# plataforma se desarrollará con el fin de permitir a los usuarios navegar,
# encontrar y alquilar en un solo lugar. La primera versión de la plataforma
# estará lista en 12 meses.
# Marketing y Ventas: RentMe estará dirigido a propietarios y inquilinos de
# Londres. Utilizará estrategias de marketing digital, publicidad en redes
# sociales, campañas de influencers, anuncios en línea y publicidad en medios
# impresos. Esperamos facturar alrededor de 5 millones de libras en el primer año.
# Equipo: RentMe estará formado por un equipo de emprendedores con experiencia en
# el sector inmobiliario. Estos profesionales se encargarán de la dirección de la
# compañía, el desarrollo de la plataforma, el marketing, el soporte técnico y la
# gestión de la empresa.
# Financiación: Se requerirán 2 rondas de capital semilla, una para el desarrollo
# de la plataforma y otra para la implementación de estrategias de marketing.
# Posteriormente, se necesitará una ronda de Series A para iniciar la
# comercialización del producto.
# --------------------------------------------------
# Nombre: ClinicUp
# Claim: "Tu clínica a un click".
# Idea de negocio: ClinicUp es una plataforma web de gestión de clinicas, que
# ofrece herramientas de software para optimizar la gestión administrativa,
# permitiendo al usuario reservar citas, pagar facturas y recibir información de
# salud con rapidez y facilidad.
# Plataforma: ClinicUp usará una plataforma SaaS basada en la nube, con un tiempo
# de desarrollo estimado de 6 meses.
# Marketing y Ventas: ClinicUp se dirige a las clinicas particulares, ofreciendo
# estrategias de marketing digital (publicidad en redes sociales, SEO, etc.) para
# llegar a ellas. Nuestra meta es facturar 500.000€ en el primer año.
# Equipo: ClinicUp está formado por un equipo de emprendedores con amplia
# experiencia en el sector, comprometidos con el proyecto.
# Financiación: Necesitamos una ronda de seed capital de 500.000€ para desarrollar
# el producto y series A por valor de 1.000.000€ para iniciar las ventas.
# --------------------------------------------------
# Nombre y claim para la startup: "BeFlex: Be flexible in healthcare".
# Idea de negocio: Un software de agenda inteligente que permite a los usuarios
# agendar citas, cancelarlas y recibir recordatorios, todo de forma segura y
# personalizada, mejorando la experiencia de los pacientes y ahorrando tiempo a
# las clínicas.
# Plataforma: Utilizando tecnología de Inteligencia Artificial para automatizar
# tareas y optimizar el uso del tiempo, buscando tardar 6 meses en desarrollar el
# primer producto vendible.
# Marketing y Ventas: Dirigido a clínicas y hospitales de Londres, utilizando
# estrategias de marketing digital para llegar a los usuarios, esperando facturar
# el primer año £200,000.
# Equipo: Un equipo de emprendedores con experiencia en tecnología y salud, con
# una pasión por innovar.
# Financiación: Necesitaremos una ronda de seed capital para desarrollar el
# producto, y series A para empezar a vender.
# --------------------------------------------------
# Nombre y claim para la startup: "Home4You: tu hogar ideal"
# Idea de negocio: Brindamos a nuestros usuarios una plataforma de inmobiliaria en
# Madrid, con un software especializado que les permite filtrar sus búsquedas por
# ubicación, estilo de vida, presupuesto, entorno y distribución de espacios.
# Plataforma: Utilizamos la última tecnología para ofrecer una experiencia única a
# nuestros usuarios. Nuestro equipo de desarrollo trabajará para tener el primer
# producto vendible en aproximadamente 6 meses.
# Marketing y Ventas: Nuestro público objetivo son personas y familias en busca de
# su hogar ideal en Madrid. Empleamos estrategias de marketing digital para llegar
# a nuestro público objetivo, así como también publicidad offline. Esperamos
# facturar 1.5 millones de euros en el primer año.
# Equipo: Somos un equipo de emprendedores formado por expertos en inmobiliaria,
# desarrolladores de software, publicistas, así como otros profesionales.
# Financiación: Necesitamos una ronda de seed capital para desarrollar el producto
# y una Serie A para empezar a vender. Estamos abiertos a la colaboración de
# inversionistas para asegurar el futuro de nuestra startup.
# --------------------------------------------------
# Nombre y claim para la startup: London Real Estate, “Tu hogar en la ciudad”.
# Idea de negocio: Ofrecemos una plataforma web interactiva en la que los usuarios
# pueden seleccionar y personalizar sus viviendas y oficinas en Londres. Esto les
# da la capacidad de visualizar cómo sería su futuro hogar/oficina antes de tomar
# una decisión.
# Plataforma: Usamos tecnología de inteligencia artificial y análisis predictivo
# para identificar las principales tendencias de mercado, adaptando nuestros
# resultados a los deseos de nuestros usuarios. Esto nos permitirá lanzar nuestro
# primer producto vendible en menos de 12 meses.
# Marketing y Ventas: Nuestra audiencia son principalmente profesionales y
# empresas, que buscan una solución rápida y sencilla para encontrar y alquilar
# una vivienda/oficina en Londres. Usaremos publicidad en línea, redes sociales,
# marketing de contenido y campañas de email para llegar a nuestros usuarios.
# Esperamos facturar alrededor de 1,2 millones de libras el primer año.
# Equipo: Estamos compuestos por un equipo de expertos en tecnología,
# inmobiliaria, marketing y finanzas, todos emprendedores con una pasión
# compartida por la innovación y la creación de una plataforma única e
# interactiva.
# Financiación: Necesitamos una ronda de seed capital para desarrollar el producto
# y una serie A para empezar a vender. Estamos buscando inversores interesados en
# llevar nuestra plataforma al siguiente nivel.
# --------------------------------------------------
# Nombre y claim para la startup:
# "ClinicaGo: Tu salud a un clic"
# Idea de negocio: Ofrecer un software de gestión de clínicas digitalizado,
# totalmente personalizado, que permita a los médicos y pacientes una experiencia
# óptima, ahorrando tiempo y simplificando los procesos.
# Plataforma: Utilizaremos una plataforma basada en la nube, con la última
# tecnología y una interfaz de usuario intuitiva y amigable. El tiempo estimado
# hasta el primer producto vendible será de 3 meses.
# Marketing y Ventas: Nuestro público objetivo son clínicas y hospitales de todo
# Madrid. Estaremos presentes en las principales redes sociales, a través de
# campañas de publicidad en línea, y de patrocinios en eventos de salud. Esperamos
# facturar 1 millón de euros el primer año.
# Equipo: Somos un equipo de 3 miembros profesionales, con experiencia en el
# sector de la salud, tecnología y emprendimiento.
# Financiación: Necesitaremos 2 rondas de capital semilla para el desarrollo del
# producto, y otra ronda de inversión de Serie A para empezar a vender.
# --------------------------------------------------
# Nombre y claim para la startup: Healon - Tu salud en tus manos.
# Idea de negocio: Ofrecemos una plataforma web y móvil que conecta a los
# pacientes con los mejores médicos de Londres. Nuestro software permite a los
# pacientes reservar citas, recibir recomendaciones personalizadas, recibir
# informes médicos, etc.
#  Plataforma: Desarrollaremos nuestra plataforma usando Angular, React y Node.js.
# Esperamos tener nuestro primer producto vendible en 8 meses.
# Marketing y Ventas: Nuestro público objetivo son residentes de Londres entre 18
# y 50 años. Usaremos diferentes estrategias de marketing digital para llegar a
# ellos, incluyendo SEO, SEM y campañas de publicidad en redes sociales. Esperamos
# facturar más de £1M en el primer año.
# Equipo: Estamos formados por un equipo de 4 emprendedores con experiencia en
# software, marketing y la industria médica.
# Financiación: Necesitaremos 3 rondas de seed capital para el desarrollo de la
# plataforma, y dos rondas de series A para lanzar nuestro producto.
# --------------------------------------------------
# Nombre y claim: "BuyHome Madrid: todo lo que necesitas para tu nueva casa".
# Idea de negocio: Una plataforma e-commerce inmobiliaria para Madrid que ofrece
# una experiencia única de compra, con la garantía de los mejores precios y una
# amplia selección de propiedades.
# Plataforma: Esta plataforma se desarrollará en HTML/CSS/JS, con una interfaz
# intuitiva y una experiencia de usuario excepcional. Estimamos que el tiempo para
# el primer producto vendible será de aproximadamente 4 meses.
# Marketing y Ventas: Nuestros usuarios objetivo son la gente de Madrid que busca
# comprar una nueva casa. Usaremos estrategias de marketing digital, redes
# sociales, publicidad y SEO para llegar a ellos. Esperamos facturar al menos 5
# millones de euros el primer año.
# Equipo: Somos un equipo de emprendedores profesionales y apasionados con
# experiencia en tecnología, marketing y negocios.
# Financiación: Necesitamos una ronda inicial de seed capital para desarrollar la
# plataforma y series A para empezar a vender.
# --------------------------------------------------
# Nombre: LondonSpace - "Tu hogar, tu espacio"
# Idea de negocio: Ofrecemos una plataforma digital que conecta a demandantes de
# inmuebles con propietarios de inmuebles en Londres, permitiendo la compra y
# venta de bienes inmuebles de forma sencilla y transparente.
# Plataforma: Nuestro software está desarrollado con tecnologías avanzadas de
# machine learning y blockchain, para asegurar la seguridad y fiabilidad del
# proceso. Estaremos listos para vender en un plazo de 6 meses.
# Marketing y Ventas: Nuestro público objetivo son compradores e inversores de
# bienes raíces, a quienes llegaremos a través de campañas en redes sociales,
# anuncios en línea y publicidad en radio y televisión. Esperamos facturar
# £300.000 en el primer año.
# Equipo: Nuestro equipo es joven y dinámico, compuesto por 5 expertos en
# desarrollo de software, marketing y finanzas.
# Financiación: Necesitamos una ronda de seed capital de £200.000 para desarrollar
# el producto, y otra ronda de series A de £300.000 para empezar a vender.
# --------------------------------------------------
# Nombre y claim: MyClinic - "Tu clínica digital"
# Idea de negocio: MyClinic es una plataforma web con un modelo freemium que
# conecta a pacientes con profesionales de la salud en Madrid. Ofrecemos una
# experiencia única de búsqueda, selección y gestión de citas con profesionales
# médicos y otros servicios de salud.
# Plataforma: Usaremos tecnologías de última generación para desarrollar una
# plataforma web y móvil fácil de usar para los usuarios finales. Esperamos lanzar
# el primer producto dentro de un plazo de 12 meses.
# Marketing y Ventas: Nuestros clientes objetivo son usuarios finales de todas las
# edades y profesionales de la salud de Madrid. Utilizaremos técnicas de marketing
# digital, SEO, publicidad, etc. para llegar a ellos. Esperamos facturar 1 millón
# de euros el primer año.
# Equipo: Nuestro equipo emprendedor está formado por 5 miembros con experiencia
# en el sector de la salud, tecnología y marketing.
# Financiación: Necesitamos una ronda de seed capital para el desarrollo del
# producto y una ronda de Series A para el lanzamiento y la venta.
# --------------------------------------------------
# Nombre y Claim: "CareOn: Cuidado de salud inteligente".
# Idea de negocio: Ofreceremos una plataforma de software inteligente para la
# gestión de clinicas, que incluirá seguimiento de pacientes, gestión de citas,
# análisis de datos, administración de inventario, etc. Ofreceremos un modelo
# freemium, con una versión gratuita para usuarios básicos, y una versión premium
# para usuarios avanzados.
# Plataforma: Usaremos tecnología cloud para desarrollar la plataforma, y
# esperamos tardar 18 meses en lanzar el primer producto vendible.
# Marketing y Ventas: Nuestro producto está destinado a clinicas de Londres, y
# usaremos estrategias de marketing digital y redes sociales para llegar a ellas.
# Esperamos facturar alrededor de 500.000 libras durante el primer año.
# Equipo: Nuestro equipo emprendedor está formado por una mezcla de profesionales
# de la salud, programadores y expertos en marketing.
# Financiación: Necesitaremos una ronda de seed capital para desarrollar el
# producto y una ronda de Series A para empezar a vender.
# --------------------------------------------------
# Nombre y claim para la startup: MadridHome, "Tu hogar, tu propiedad".
# Idea de negocio: Ofrecer una plataforma digital con la que propietarios,
# compradores y gestores inmobiliarios se unan para simplificar la compra, venta y
# gestión de propiedades en Madrid. Plataforma: Usaremos la tecnología de
# blockchain para automatizar el proceso de compraventa y ofreceremos una versión
# freemium y una premium con más funcionalidades. Necesitaremos aproximadamente un
# año para lanzar nuestro primer producto vendible.
# Marketing y Ventas: Estaremos enfocados en propietarios, compradores y gestores
# inmobiliarios de Madrid. Utilizaremos estrategias de marketing en línea para
# llegar a nuestro público objetivo y esperamos facturar alrededor de 1 millón de
# euros el primer año.
# Equipo: Estamos formado por un equipo de 4 profesionales especializados en
# inmobiliaria con experiencia en tecnología de blockchain.
# Financiación: Necesitaremos una ronda de seed capital para desarrollar el
# producto y series A para empezar a vender.
# --------------------------------------------------
# Nombre y claim para la startup: "Londres Home: el lugar para encontrar tu
# hogar".
# Idea de negocio: Ofrecemos una plataforma en línea de inmobiliaria innovadora,
# ofreciendo una herramienta intuitiva para encontrar el hogar ideal para los
# compradores. Con un software único, ofrecemos una experiencia personalizada de
# búsqueda.
# Plataforma: Utilizaremos tecnología de IA para optimizar la búsqueda y optimizar
# los resultados de búsqueda. Estaremos listos para el primer producto en un plazo
# de seis meses.
# Marketing y Ventas: Dirigido a compradores y vendedores en Londres, usaremos SEO
# y SEM para llegar a nuestro público. Esperamos facturar 1 millón de libras en el
# primer año.
# Equipo: El equipo emprendedor consiste en un equipo de expertos en inmobiliaria,
# tecnología, marketing y ventas.
# Financiación: Necesitaremos dos rondas de seed capital para desarrollar el
# producto y una ronda de series A para empezar a vender.
# --------------------------------------------------
# Nombre y claim para la startup:
# ClinicaReady: "Tu salud, en el momento que lo necesitas".
# Idea de negocio:
# Un software de clinicas con modelo pay-per-use que brinda servicios de salud y
# bienestar a través de una plataforma digital, ofreciendo servicios médicos de
# forma rápida, segura y accesible.
# Plataforma:
# Usaremos la tecnología de inteligencia artificial para que los usuarios puedan
# acceder de forma segura a sus servicios médicos desde cualquier lugar y en el
# momento que lo necesiten. Estamos trabajando para tener el producto listo para
# su lanzamiento en 6 meses.
# Marketing y Ventas:
# Nuestro producto va dirigido a la comunidad de Madrid, ofreciendo servicios de
# salud accesibles y económicos. Usaremos estrategias de marketing digital para
# llegar a nuestros clientes. Esperamos facturar un total de 500.000 euros el
# primer año.
# Equipo:
# Nuestro equipo está compuesto por emprendedores con un profundo conocimiento en
# el ámbito de la salud y la tecnología. Estamos comprometidos con la innovación y
# estamos trabajando para desarrollar un producto único.
# Financiación:
# Necesitamos de una ronda de seed capital para desarrollar el producto y una
# ronda de series A para iniciar las ventas. Estamos abiertos a inversiones que
# nos aporten un valor añadido.
# --------------------------------------------------
# Nombre y claim: "ClinPlus - Tu salud, nuestra prioridad".
# Idea de negocio: Un software innovador que ofrece servicios médicos a través de
# un modelo pay-per-use. El software se enfoca en optimizar el flujo de trabajo de
# clínicas, aumentar la satisfacción del paciente y aumentar la eficiencia de los
# servicios. Plataforma: Utilizaremos una plataforma tecnológica basada en la nube
# para ofrecer una experiencia de usuario intuitiva para todos los usuarios.
# Estimamos que tardaremos 6 meses en lanzar nuestro primer producto vendible.
# Marketing y Ventas: Nuestra estrategia de marketing estará dirigida a clínicas
# de Londres. Utilizaremos anuncios en redes sociales, publicidad en línea,
# campañas de email y SEO. Esperamos facturar alrededor de £1.2M el primer año.
# Equipo: Nuestro equipo está compuesto por un equipo de profesionales formado por
# médicos, ingenieros de software y expertos en marketing. Financiación:
# Necesitaremos una ronda de capital semilla para desarrollar el producto y una
# serie A para comenzar a vender el producto.
# --------------------------------------------------
# Nombre y claim para la startup:
# RentHouse - "Vive sin compromiso".
# Idea de negocio: Ofrecer alquiler de inmuebles de manera flexible, sin
# compromisos a largo plazo, gracias a una plataforma web innovadora.
# Plataforma: Usaremos tecnología web dinámica para ofrecer alquileres de corta
# temporada con tarifas personalizadas. Estimamos que llegaremos al primer
# producto vendible en 6 meses.
# Marketing y Ventas: Nuestros clientes son empresas y particulares con deseo de
# vivir sin compromisos a largo plazo. Usaremos estrategias online y offline para
# llegar a nuestro público y estimamos facturar el primer año 1 millón de euros.
# Equipo: Un equipo de 5 profesionales con experiencia en inmuebles, tecnología y
# marketing.
# Financiación: Necesitamos una ronda de seed capital para desarrollar el producto
# y otra de series A para empezar a vender.
# --------------------------------------------------
# Nombre y claim: "UrbanShare: tu solución de alojamiento compartido".
# Idea de negocio: Ofrecemos un servicio de alquiler a corto plazo a personas y
# empresas, con un modelo pay-per-use, mediante el uso de un software de inmuebles
# compartidos en Londres. Nuestro valor añadido es la flexibilidad y la comodidad,
# con tarifas más bajas y más opciones de alojamiento.
# Plataforma: Utilizaremos una plataforma en la nube para desarrollar nuestro
# software, lo que nos permitirá entregar un producto de calidad en el menor
# tiempo posible.
# Marketing y Ventas: Nuestro público objetivo serán las personas y empresas de
# Londres que buscan alojamiento temporal. Utilizaremos una estrategia de
# marketing digital para llegar a ellos y esperamos facturar 1 millón al año.
# Equipo: Contamos con un equipo de cinco profesionales de inmuebles, con amplia
# experiencia en el sector.
# Financiación: Requerimos una ronda de seed capital para desarrollar el producto
# y una serie A para empezar a vender.
# --------------------------------------------------
