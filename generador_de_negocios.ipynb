# %%
# Creating some synthetic data for fine-tuning 
# We are going to create serveral characters for video games in here: 

import os
import openai
import pandas as pd

# Set your OpenAI API key
openai.api_key = os.getenv("OPENAI_API_KEY")

# Define input values
negocios = ['B2B', 'B2C'] 
industrias = ['clinicas', 'inmobiliaria']
ubicaciones = ['madrid','londres'] 

# Create an empty list to store results
results = []

# Loop through input values
record_number = 1
for negocio in negocios:
    for industria in industrias:
        for ubicacion in ubicaciones:
            # Define the prompt with placeholders
            prompt = f"Eres un analista con muchos años de experiencia en software y sistemas SaaS. Crea una idea de negocio para una startup innovadora que desarrolla un SaaS {negocio} en el sector de {industria}, y que está ubicada en {ubicacion} siguiendo estas instrucciones: detalla a quién se dirige, la diferenciación, modelo de negocio, equipo emprendedor, procura utilizar un tono como si fueras el emprendedor, y utiliza 100 palabras en total."

            # Generate the response using OpenAI's GPT-3 model
            response = openai.Completion.create(
                model="text-davinci-003",
                prompt=prompt,
                temperature=0.7,  # Adjust temperature for response creativity
                max_tokens=200,  
                n=1,  # Generate a single response
                stop=None,  # Let the model determine when to stop
            )

            # Extract and store the response text
            response_text = response.choices[0].text.strip()

            # Create a subprompt string
            subprompt = f"{negocio}, {industria}, {ubicacion}"

            # Store the results in a dictionary
            result = {
                'record number': record_number,
                'negocio': negocio,
                'industria': industria,
                'ubicacion': ubicacion,
                'prompt': prompt,
                'subprompt': subprompt,
                'response': response_text
            }

            results.append(result)

            # Increment the record number
            record_number += 1

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
df.to_csv("saas.csv", index=False)

# %%
import textwrap

# Assuming you have a DataFrame named 'df' with a column named 'response'
for paragraph in df['response']:
    paragraphs = paragraph.split('\n')  # Split by line breaks
    for p in paragraphs:
        wrapped_paragraphs = textwrap.wrap(p, width=80)  # Adjust the width as needed
        for wrapped_p in wrapped_paragraphs:
            print(wrapped_p)
    print('-' * 50)  # Add a line break separator
# Out:
# Mi nueva startup innovadora se dirige a clínicas de todo el país. Estamos
# desarrollando un sistema SaaS B2B para ayudar a mejorar los flujos de trabajo y
# las operaciones de las clínicas. Nuestro sistema es único porque se enfoca en la
# automatización del proceso de facturación para ahorrar tiempo y reducir errores.
# Esto también permitirá a las clínicas procesar los pagos de los clientes de
# forma rápida y segura.
# Nuestro modelo de negocio se basa en cobrar una tarifa mensual por el uso del
# sistema. Esto significa que nuestros clientes pueden
# --------------------------------------------------
# Mi nombre es John y soy el fundador de ClinicSaaS, una nueva empresa de software
# basada en Londres. ClinicSaaS ofrece una plataforma de software empresarial
# (SaaS) B2B a clínicas en todo el mundo. Nuestro objetivo es ayudar a las
# clínicas a simplificar sus procesos de administración, desde la gestión de citas
# hasta la facturación.
# Nuestro producto se diferencia de otros servicios similares porque se centra en
# la satisfacción del cliente. Ofrecemos una interfaz intuitiva que permite a los
# usuarios navegar por la plataforma con facilidad. También contamos con un equipo
# de sop
# --------------------------------------------------
# Mi nueva startup innovadora, ubicada en Madrid, se llama SaaS B2B Inmobiliaria.
# Está dirigida a empresas de inmobiliaria que buscan una solución de software de
# alto rendimiento para administrar sus operaciones. Nuestra solución se destaca
# por ofrecer una experiencia de usuario sencilla y una interfaz intuitiva que
# permite a los usuarios realizar tareas comerciales de forma rápida y eficiente.
# Nuestro modelo de negocio se basa en una suscripción mensual para el acceso a
# nuestro software. Esto nos permitirá ofrecer un precio asequible para los
# usuarios con una experiencia superior. Nuestro equipo empre
# --------------------------------------------------
# Mi startup innovadora se llama House Brokers. Nuestro servicio está dirigido a
# inmobiliarias, agentes y compradores de propiedades en Londres. Ofrecemos una
# plataforma de servicios SaaS B2B que ayuda a simplificar el proceso de compra y
# venta de inmuebles. Esta plataforma hace que sea más fácil para los compradores
# encontrar propiedades, hacer ofertas y cerrar el acuerdo. Para los agentes de
# bienes raíces, ofrecemos herramientas para anunciar sus propiedades, conectar
# con los compradores y obtener una comisión por cada operación. Nuestra principal
# diferenciación es la facilidad de uso y
# --------------------------------------------------
# Mi startup innovadora se llama Clinicas2Go, y se dirige a clínicas, proveedores
# de salud y a sus pacientes. El objetivo de esta startup es ofrecer una nueva
# forma de proporcionar servicios médicos a través de un sistema de Software como
# Servicio (SaaS) B2C. El sistema permitirá a cualquier clínica ofrecer una amplia
# gama de servicios a través de una plataforma web, incluyendo consultas,
# reservas, pagos, informes médicos, etc.
# La principal característica diferenciadora de Clinicas2Go es que ofrecerá una
# interfaz mucho más intuitiva y fácil de usar
# --------------------------------------------------
# Soy un emprendedor de Londres con una idea innovadora para una startup SaaS B2C
# en el sector de clínicas. Esta startup se dirige a los clientes de clínicas de
# todo el mundo, con un enfoque especial en los distintos mercados europeos. La
# diferenciación de nuestra empresa es que ofrecemos una solución única para el
# seguimiento y análisis de los resultados de los servicios de clínicas, al mismo
# tiempo que permite a los clientes acceder fácilmente a información relevante.
# El modelo de negocio de esta empresa se basa en una suscripción anual para cada
# usuario, con tar
# --------------------------------------------------
# Mi startup innovadora se llama HomeSmartly. Está ubicada en Madrid y se dedica a
# desarrollar un software SaaS B2C para el sector de la inmobiliaria. Está
# orientada a personas que quieren comprar, vender o alquilar inmuebles.
# HomeSmartly ofrece información actualizada y personalizada sobre el mercado
# inmobiliario en Madrid. Nuestra principal diferenciación es que ofrecemos un
# servicio que se ajusta a las necesidades específicas y preferencias de cada
# usuario.
# Nuestro modelo de negocio se basa en la suscripción a nuestro servicio, con
# planes de pago mensual, trimestral o anual. Nuestra plataforma tamb
# --------------------------------------------------
# Mi idea de negocio para esta startup innovadora se centra en ofrecer una
# plataforma SaaS B2C para el sector inmobiliario en Londres. Esta plataforma se
# dirigirá a propietarios de inmuebles, profesionales inmobiliarios y compradores.
# Nuestra diferenciación estará en nuestro enfoque centrado en el cliente, que se
# traducirá en una experiencia de uso intuitiva y fácil de usar. Ofreceremos una
# interfaz de usuario moderna y una amplia variedad de funciones avanzadas. Esto
# permitirá a los usuarios buscar, comparar y seleccionar propiedades de manera
# eficiente y sencilla.
# --------------------------------------------------
