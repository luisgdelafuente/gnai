# %%
# Creating some synthetic data for fine-tuning 
# We are going to create serveral characters for video games in here: 

import os
import openai
import pandas as pd

# Set your OpenAI API key
openai.api_key = os.getenv("OPENAI_API_KEY")

# Define input values
industrias = ['clinicas', 'inmobiliaria', 'talleres mecanicos']
financiaciones = ['bootstrapped', '500000€ capital semilla'] 
ubicaciones = ['madrid','valencia'] 

# Create an empty list to store results
results = []

# Loop through input values
record_number = 1
for industria in industrias:
    for financiacion in financiaciones:
        for ubicacion in ubicaciones:
            # Define the prompt with placeholders
            prompt = f"Eres un analista con muchos años de experiencia en startups y nuevos negocios. Crea una idea de negocio innovadora para una startup en el sector de {industrias}, sabiendo que cuenta con financiación: {financiaciones}, y que está ubicada en {ubicaciones}. Escribe sólo la idea como si fueras el emprendedor, con tono apasionado pero profesional. Aprovechando las especificidades de ubicación, industria y financiación disponibles."

            # Generate the response using OpenAI's GPT-3 model
            response = openai.Completion.create(
                model="text-davinci-003",
                prompt=prompt,
                temperature=0.7,  # Adjust temperature for response creativity
                max_tokens=250,  # Limit response to 100 tokens (adjust as needed)
                n=1,  # Generate a single response
                stop=None,  # Let the model determine when to stop
            )

            # Extract and store the response text
            response_text = response.choices[0].text.strip()

            # Create a subprompt string
            subprompt = f"{industria}, {financiacion}, {ubicacion}"

            # Store the results in a dictionary
            result = {
                'record number': record_number,
                'industria': industria,
                'financiacion': financiacion,
                'ubicacion': ubicacion,
                'prompt': prompt,
                'subprompt': subprompt,
                'response': response_text
            }

            results.append(result)

            # Increment the record number
            record_number += 1

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
df.to_csv("startups.csv", index=False)

# %%
import textwrap

# Assuming you have a DataFrame named 'df' with a column named 'response'
for paragraph in df['response']:
    paragraphs = paragraph.split('\n')  # Split by line breaks
    for p in paragraphs:
        wrapped_paragraphs = textwrap.wrap(p, width=80)  # Adjust the width as needed
        for wrapped_p in wrapped_paragraphs:
            print(wrapped_p)
    print('-' * 50)  # Add a line break separator
# Out:
# La idea de negocio innovadora para una startup es una aplicación para clínicas
# que se centrará en Madrid y Valencia para aprovechar la ubicación. Se ofrecerá a
# los pacientes una herramienta que les permitirá programar citas con los médicos
# de forma rápida y sencilla, así como encontrar información relevante sobre los
# servicios y tratamientos ofrecidos. La aplicación también ofrecerá a los médicos
# la posibilidad de administrar sus consultas de forma eficiente y monitorizar los
# resultados de los pacientes. Esto permitirá a los médicos obtener una mejor
# comprensión de los datos de sus pacientes y tomar mejores decisiones clínicas.
# La aplicación se financiará con el capital semilla de 500.000€ para el
# desarrollo de la aplic
# --------------------------------------------------
# Idea de negocio para una startup:
# Una plataforma digital centrada en la región de Madrid y Valencia para conectar
# a los usuarios de clínicas, inmobiliarias, y talleres mecánicos. Esta plataforma
# proporcionará una solución integral para todos los servicios relacionados con
# estos sectores, desde el registro de nuevos clientes hasta el seguimiento de los
# trabajos realizados, pasando por ofertas especiales para los usuarios.
# La plataforma se financiará con los 500.000€ de capital semilla, y se
# aprovechará la inversión de bootstrapping para el desarrollo del producto, así
# como para la promoción de la plataforma. Esta se promocionará a través de
# anuncios en medios digitales locales, campañas de marketing en redes sociales,
# así como a través
# --------------------------------------------------
# La idea es crear una startup de inmobiliaria especializada en Madrid y Valencia,
# centrada en la rehabilitación de edificios mejorando el entorno urbano. La
# propuesta está dirigida a propietarios con un presupuesto asequible, que quieran
# mejorar la calidad de sus inmuebles. Esta startup se financiará con 500000€ de
# capital de semilla, para lo cual se contratará un equipo de expertos en
# inmobiliaria, arquitectura y rehabilitación para gestionar los proyectos con
# éxito. Además, se puede bootstrapping para financiar los primeros proyectos, con
# la posibilidad de ofrecer financiación a largo plazo a los propietarios. Esta
# startup se enfocará en la renovación de edificios en comunidades de vecinos,
# talleres mecánicos y clínicas para mejorar la calidad de vida de los vec
# --------------------------------------------------
# Una idea innovadora para una startup en el sector de clínicas en Madrid, con
# financiación bootstrapped, podría ser una plataforma de telemedicina. La
# plataforma permitirá a los pacientes consultar con médicos de forma segura y
# remota. Esto permitirá a los pacientes obtener un diagnóstico y tratamiento
# inmediatos sin salir de casa, reduciendo los costos y mejorando la eficiencia.
# La plataforma se integrará con servicios de pago para permitir que los pacientes
# paguen por su consulta en línea. Esto permitirá a los médicos y clínicas
# aprovechar al máximo la financiación inicial bootstrapped disponible.
# Una idea innovadora para una startup inmobiliaria en Valencia, con financiación
# de 500.000 € de capital semilla, podría ser una plata
# --------------------------------------------------
# Mi idea de negocio innovadora para una startup ubicada en Madrid es una clínica
# de atención primaria digital. Utilizando una mezcla de tecnologías de última
# generación, se ofrecerá a los pacientes una atención primaria sin salir de casa.
# Esta clínica digital ofrecerá servicios como consultas virtuales con médicos,
# tratamientos remotos, recetas electrónicas y pruebas de diagnóstico a distancia.
# Esta clínica digital se financiará con el capital semilla de 500.000€, así como
# con el financiamiento de capital riesgo y crowdfunding. Además, se ofrecerán
# servicios de atención primaria gratuitos a los pacientes de bajos ingresos. El
# objetivo es mejorar la atención primaria en Madrid, proporcionando una solución
# más eficiente,
# --------------------------------------------------
# Una idea de negocio innovadora para una startup ubicada en Madrid y financiada
# con 500.000€ de capital semilla en el sector de clínicas, sería la creación de
# una cadena de clínicas móviles de alto nivel, especializadas en el cuidado de la
# salud y el bienestar de los profesionales de la ciudad. Estas clínicas estarían
# equipadas con tecnología de última generación, para ofrecer una amplia variedad
# de servicios médicos, desde consultas médicas y pruebas diagnósticas hasta
# tratamientos especializados y rehabilitación. Además, estas clínicas ofrecerían
# servicios de coaching y asesoramiento para mejorar la nutrición y el estilo de
# vida de los profesionales de Madrid. Esto permitiría a los profesionales de
# Madrid tener acces
# --------------------------------------------------
# Una idea de negocio innovadora para una startup en el sector de inmobiliaria,
# ubicada en Madrid y con 500.000€ de capital semilla es una plataforma de
# inmobiliarias colaborativas. Esta plataforma permitiría a los usuarios publicar
# sus bienes inmuebles para alquilar o vender en la web, con el objetivo de
# facilitar el acceso a una lista de inmuebles cercana a la zona de Madrid. Los
# usuarios podrán elegir entre alquileres a corto, medio y largo plazo, así como
# la venta de viviendas, oficinas, locales comerciales y terrenos. Además, los
# propietarios de inmuebles podrán obtener asesoramiento y ayuda para el
# mantenimiento y mejora de los bienes inmuebles. Esta plataforma permitirá a los
# usuarios acceder a una gran varied
# --------------------------------------------------
# La idea de negocio innovadora para una startup en el sector de inmobiliaria en
# Madrid con financiación bootstrapped es crear una plataforma online para
# facilitar el proceso de alquiler de viviendas. Esta plataforma se enfocaría en
# simplificar y mejorar el proceso de búsqueda para inquilinos y propietarios.
# Esto incluiría un motor de búsqueda inteligente para encontrar la mejor vivienda
# a precios asequibles, herramientas de evaluación de viviendas para comparar
# ofertas, una herramienta de cálculo de costos para los inquilinos y la
# posibilidad de hacer un seguimiento de los pagos de alquiler. Esta plataforma
# también permitiría a los propietarios publicar anuncios, realizar seguimiento de
# alquileres, gestionar pagos de alquiler y comunic
# --------------------------------------------------
# Mi idea de negocio innovadora para una startup en el sector de clínicas es crear
# una plataforma web que permita a los pacientes de Madrid y Valencia programar
# citas médicas con los mejores profesionales de la zona. Esta plataforma, que se
# financiaría con el capital semilla de 500000€, ofrecería a los pacientes la
# posibilidad de reservar una cita y conocer el precio del tratamiento antes de
# acudir a la clínica. Esta plataforma permitiría a las clínicas ofrecer un
# servicio de calidad con la ayuda de un enfoque basado en la tecnología para
# mejorar la experiencia del paciente y aumentar la fidelización de los mismos.
# Esta plataforma ofrecería también la opción de pagar online, lo que permitiría
# ahorrar tiempo a los pacientes. Esta plataforma
# --------------------------------------------------
# Mi idea de negocio innovadora para una startup en el sector de inmobiliaria es
# una plataforma de bienes raíces en línea para el alquiler de viviendas de lujo
# en Madrid y Valencia. Esta nueva plataforma permitirá a los propietarios de
# viviendas de lujo localizadas en Madrid y Valencia publicar sus propiedades para
# el alquiler, mientras que los inquilinos podrán buscar y reservar por adelantado
# sus propiedades en línea. Esta plataforma será financiada con el capital semilla
# de 500.000€. La plataforma se desarrollará con bootstrapping, lo que significa
# que el equipo de desarrollo se encargará de crear y mantener toda la
# infraestructura necesaria para el funcionamiento de la aplicación.
# --------------------------------------------------
# Nuestra idea de negocio innovadora para la startup se centrará en el sector de
# talleres mecánicos, ubicada en Madrid. El enfoque será la creación de una red de
# talleres mecánicos especializados, que ofrezcan servicios de mantenimiento y
# reparación de vehículos a precios competitivos y de calidad. Esto se hará
# aprovechando la financiación bootstrapped disponible, para desarrollar una
# plataforma de software para la gestión de los talleres mecánicos, que permita a
# los clientes realizar reservas de servicios de forma rápida y sencilla. Esta
# plataforma se pondrá en marcha en Madrid, y se usará el capital semilla de
# 500.000€ para expandir la red de talleres mecánicos hacia otras ciudades como
# Valencia. De esta forma, se podrán of
# --------------------------------------------------
# Mi idea de negocio innovadora para una startup es la creación de una red de
# clínicas con servicio de emergencia basadas en Madrid y Valencia. Estas clínicas
# estarían equipadas con los últimos avances tecnológicos y ofrecerían una amplia
# gama de servicios médicos a precios asequibles para los pacientes. Se trataría
# de una startup bootstrapped con un capital semilla de 500 000€, por lo que se
# buscarían alianzas con inmobiliarias locales para obtener locales a un precio
# razonable. Además, se buscarían contactos con talleres mecánicos para conseguir
# descuentos en la compra de equipamiento médico y para el mantenimiento de los
# mismos. Esta red de clínicas permitiría a los pacientes acceder a servicios
# médicos de calidad a precios asequibles
# --------------------------------------------------
