# %%
# Combine up to 5 parameters to create startup ideas 

import os
import openai
import pandas as pd

# Set your OpenAI API key
openai.api_key = os.getenv("OPENAI_API_KEY")

# Define input values (very limited scope for demo purposes)
industries = ['clean energy', 'health']
models = ['subscription', 'e-commerce']
fundings = ['pre-seed', 'seed']
locations = ['london', 'berlin']
targets = ['generation X', 'millennials']

# Create an empty list to store results
results = []

# Loop through input values
record_number = 1
for industry in industries:
    for model in models:
        for funding in fundings:
            for location in locations:
                for target in targets:
                    # Define the prompt
                    prompt = f"Create an original and innovative business idea in 50 words for an innovative startup in the {industry} industry that targets {target} among other segments . The business model will be {model}, based in {location}, and funded through {funding}. Use the following paragraphs: Name: short and catchy name followed by a claim, and Business idea: description of the business idea. Style: write like a business founder, passionate, optimistic and professional. "

                    # Generate the response using OpenAI's GPT-3 model
                    response = openai.Completion.create(
                        model="text-davinci-003",
                        prompt=prompt,
                        temperature=0.7,
                        max_tokens=500,
                        frequency_penalty=0,
                        n=1,
                        stop=None,
                    )

                    # Extract and store the response text
                    response_text = response.choices[0].text.strip()

                    # Create a subprompt string
                    subprompt = f"{industry}, {model}, {funding}, {location}, {target}"

                    # Store the results in a dictionary
                    result = {
                        'record number': record_number,
                        'industry': industry,
                        'model': model,
                        'funding': funding,
                        'location': location,
                        'target': target,
                        'prompt': prompt,
                        'subprompt': subprompt,
                        'response': response_text
                    }

                    results.append(result)

                    # Increment the record number
                    record_number += 1

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
# df.to_csv("startup_ideas.csv", index=False)

# Print the ideas

import textwrap

for paragraph in df['response']:
    paragraphs = paragraph.split('\n')  # Split by line breaks
    for p in paragraphs:
        wrapped_paragraphs = textwrap.wrap(p, width=80)  # Adjust the width as needed
        for wrapped_p in wrapped_paragraphs:
            print(wrapped_p)
    print('-' * 50)  # Add a line break separator
# Out:
# Name: GreenEase - "Unlock Clean Energy, Easily"
# Business Idea: GreenEase is a subscription-based clean energy startup in London.
# We provide an easy and affordable way for Generation X to unlock clean energy,
# without having to worry about the hefty upfront investment. We offer a
# comprehensive package of solar panels and other clean energy solutions, tailored
# to each customer’s needs and budget. Our goal is to make access to clean energy
# simple and convenient.
# --------------------------------------------------
# Name: Greenly, The Clean Energy Subscription Revolution.
# Business Idea: Greenly is a subscription-based clean energy startup
# revolutionizing the way millennials power their lives. We provide our members
# with access to innovative clean energy solutions, including solar, wind, and
# geothermal, as well as access to our exclusive green-living community. With
# Greenly, you can power your life with clean energy — guilt-free!
# --------------------------------------------------
# Name: iGENX Energy - Powering the Future of Generation X
# Business Idea: iGENX Energy is a clean energy startup in Berlin that provides
# subscription-based green energy solutions to Generation X households. We use
# current technologies to create innovative energy products that reduce energy
# costs, lower carbon emissions, and promote sustainable living. We’re committed
# to providing cost-effective energy solutions that make a positive impact on the
# environment.
# --------------------------------------------------
# Name: CleanlyEco: Powering the Future Subscription-Style.
# Business Idea: CleanlyEco is the innovative subscription-based startup that
# provides clean energy to millennials and beyond. Our mission is to make clean
# energy accessible and affordable to everyone. We are based in Berlin, and funded
# through pre-seed investments. We offer customized clean energy plans tailored to
# the needs of our customers, and make it easy to transition to a more eco-
# friendly lifestyle.
# --------------------------------------------------
# Name: Bright Future - "The Future of Clean Energy"
# Business Idea: Bright Future is a London-based subscription-based clean energy
# startup, designed to help Generation X and other consumers to make the switch to
# renewable energy sources. We provide access to green energy sources and
# services, helping our customers save money and have a positive environmental
# impact. Our innovative technologies and services help customers save money on
# their electricity bills while reducing their carbon footprints. Bright Future
# helps to make the switch to clean energy sources easy and affordable.
# --------------------------------------------------
# Name: Bright-E - Unlocking Clean Energy for Millennials
# Business Idea: Bright-E is a clean energy startup based in London that is
# revolutionizing the way millennials access clean energy. We provide a
# subscription-based service that gives millennials access to the latest renewable
# technologies, allowing them to reduce their environmental impact and save money.
# With our easy-to-use platform, we are empowering millennials to take control of
# their energy consumption and be part of the clean energy revolution.
# --------------------------------------------------
# Name: Revolt Renewables - "Energizing the Future"
# Business Idea: Revolt Renewables is a subscription-based clean energy startup in
# Berlin, providing innovative, cost-effective solutions for Generation X and
# other segments. We will provide custom renewable energy solutions tailored to
# individual needs, with a focus on sustainability and affordability. Our goal is
# to revolutionize the energy industry and empower our customers to make smarter,
# more eco-friendly decisions.
# --------------------------------------------------
# Name: GreenGen - “Powering the Future of Clean Energy”
# Business Idea: GreenGen is an innovative subscription-based startup that
# provides clean energy solutions to Millennials and other customers in Berlin. We
# offer easy-to-understand energy plans and packages that are tailored to meet the
# needs of individuals, families and businesses. Our goal is to make clean energy
# accessible and affordable to everyone. We are currently seeking seed funding to
# launch our venture.
# --------------------------------------------------
# Name: GreenGo - "Changing the way Gen X powers the future".
# Business Idea: GreenGo is an e-commerce platform that revolutionizes the clean
# energy industry. We provide an innovative solution to the energy needs of
# Generation X by offering renewable energy options at competitive prices. We are
# based in London and are funded through pre-seed. We are committed to providing a
# sustainable and affordable alternative to traditional energy sources.
# --------------------------------------------------
# Name: EcoEco - “Empowering a Sustainable Future”
# Business Idea: EcoEco is an e-commerce platform that offers renewable energy
# solutions to millennials and other customers. We provide solar and wind power
# products such as panels, turbines, and batteries, as well as energy efficiency
# products such as LED lighting and smart thermostats. Our goal is to make
# renewable energy accessible to everyone and help reduce our carbon footprint.
# --------------------------------------------------
# Name: CleanEco - "Live Clean, Live Eco"
# Business Idea: CleanEco is an e-commerce startup based in Berlin focused on
# supplying clean energy solutions to Generation X. We provide eco-friendly
# products such as energy-saving devices, solar power generators, and other
# renewable energy solutions. Our mission is to make clean and renewable energy
# accessible and affordable for everyone. By investing in our pre-seed funding,
# you will help us make a positive change for the environment.
# --------------------------------------------------
# Name: BrightEco - "Clean energy for a brighter future."
# Business Idea: BrightEco is an innovative e-commerce startup in the clean energy
# industry, based in Berlin. Our mission is to make clean energy more accessible
# and sustainable for millennials and beyond. We will offer a wide range of
# services such as clean energy consultancy, renewable energy product sales, and
# energy efficiency solutions. Our goal is to make the shift to clean energy
# easier and more affordable for everyone.
# --------------------------------------------------
# Name: GenX Energy Solutions - "The Future of Clean Energy"
# Business idea: GenX Energy Solutions develops innovative clean energy solutions
# for Generation X customers. We provide a range of products and services, from
# solar panels to wind turbines, all accessible through our e-commerce platform.
# Our London-based business is dedicated to making clean energy more affordable
# and accessible to everyone. We're committed to creating a better future for our
# planet and our customers.
# --------------------------------------------------
# Name: CleanEco – “A New Way to Clean Energy”
# Business Idea: CleanEco is an e-commerce platform that will provide innovative,
# affordable solutions for clean energy production. We cater to millennials and
# other consumers, providing cutting-edge technology, advice and educational
# resources on clean energy production. We will work with a wide range of
# suppliers in London to provide a comprehensive range of products, from solar
# panels to wind turbines. Our mission is to help reduce carbon emissions and
# create a sustainable future.
# --------------------------------------------------
# Name: EnergizeX - Unlocking Clean Energy for Generation X.
# Business Idea: EnergizeX is an e-commerce platform that helps Generation X
# transition to clean energy. We provide expert guidance, innovative products, and
# convenient services that make it easier for people to switch to clean energy. We
# are based in Berlin and are funded through seed capital.
# --------------------------------------------------
# Name: Green Fuse - "A Spark of Clean Energy".
# Business Idea: Green Fuse is an online e-commerce startup in the clean energy
# industry, based in Berlin and funded through seed. We provide renewable energy
# solutions to millennials, with a focus on sustainability and affordability. Our
# mission is to make clean energy more accessible and affordable, so that everyone
# can enjoy the benefits of renewable energy sources.
# --------------------------------------------------
# Name: GenXFit. "Achieve a healthier life in a few clicks".
# Business Idea: GenXFit is an innovative health startup in London that offers a
# monthly subscription service to Generation X. We offer personalized workout
# plans and nutrition advice, helping our clients to reach their desired level of
# fitness and health. Our service is accessible, affordable and effective,
# allowing our clients to achieve their goals easily and conveniently.
# --------------------------------------------------
# Name: "Fettle: Get Fit, Feel Good"
# Business Idea: Fettle is a subscription-based health startup providing
# innovative wellness solutions for millennials in London. We offer custom-
# tailored lifestyle plans, state-of-the-art fitness equipment and certified
# nutritionists to help our customers achieve their fitness goals. We are funded
# through pre-seed and use the latest technology to help our customers get fit,
# stay healthy, and feel good.
# --------------------------------------------------
# Name: X Health Berlin - "Stay Healthy, Live Well!"
# Business idea: X Health Berlin is a subscription-based health startup that
# focuses on providing personalized health solutions to Generation X in Berlin. We
# offer a broad range of services, including personalized lifestyle coaching,
# nutrition advice and physical activity tracking. Our goal is to help people stay
# healthy and live well.
# --------------------------------------------------
# Name: FreshHealth, "Your Health in the Palm of Your Hand"
# Business Idea: FreshHealth is an innovative subscription-based health and
# wellness startup located in Berlin. We provide young adults with access to
# affordable healthcare through a mobile app. Our comprehensive service offers
# virtual consultations with healthcare professionals, personalized health advice,
# and access to a supportive community of like-minded individuals. Our mission is
# to empower millennials to make informed decisions about their health and
# wellbeing.
# --------------------------------------------------
# Name: HealthifyX. "The Healthy Choice for Generation X."
# Business Idea: HealthifyX provides subscription-based health and wellness
# services tailored for Generation X and beyond. Our services include
# consultations with nutritionists, personal trainers, yoga instructors, and more.
# We offer access to exclusive online resources, workshops, and events in London,
# all with the goal of helping members lead healthier and happier lives.
# --------------------------------------------------
# Name: My Health Plus - “Your Health, Reinvented”
# Business Idea: My Health Plus is a subscription-based health service that caters
# to the needs of millennials in London. We provide personalized health services,
# ranging from digital health coaching, diet plans, to access to medical
# professionals. Our goal is to help millennials stay healthy, energized and
# motivated to make better lifestyle choices. We believe that with our innovative
# services, we can reinvent how people view their health.
# --------------------------------------------------
# Name: VitaFy - "The Subscription-based Health Revolution"
# Business Idea: VitaFy is a Berlin-based health startup offering an innovative
# subscription-based model that provides personalized access to health services
# and products tailored to Generation X. We seek to revolutionize healthcare by
# creating a convenient and affordable solution for busy professionals. Our
# subscription model makes it easy to access quality healthcare wherever and
# whenever you need it.
# --------------------------------------------------
# Name: Thrive Health - "Live Better, Feel Healthier"
# Business idea: Thrive Health is a subscription-based health service that is
# focused on helping millennials improve their overall wellbeing. We offer
# personalized nutrition and fitness plans, access to virtual health coaching, and
# monthly health challenges and rewards. Our goal is to help people live healthier
# and happier lives through a variety of services, tailored to meet the needs of
# each individual.
# --------------------------------------------------
# Name: FitX - 'Perfect fitness for GenX'
# Business Idea: FitX is an online health and fitness platform that provides
# tailored workouts, meal-plans and nutritional advice to help Generation X reach
# their fitness goals. Through our e-commerce based business model, we provide
# innovative, easy-to-use and convenient services at a competitive price. Our
# mission is to help GenX feel strong and confident in their own skin.
# --------------------------------------------------
# Name: VitalityX | Your Health Reimagined
# Business Idea: VitalityX is an e-commerce platform that provides a modern
# approach to health and wellness through personalized recommendations, online
# consultations, and subscription-based services. We offer a wide range of
# products, from vitamins to fitness gear, tailored to the needs of millennials
# and other health-conscious consumers. With our innovative platform, we make it
# easier than ever for customers to be proactive about their health and wellbeing.
# --------------------------------------------------
# Name: FitGenX - 'Get fit, stay fit, be fit'.
# Business Idea: FitGenX is an e-commerce health startup based in Berlin. We
# provide a range of innovative solutions to help Generation X maintain a healthy
# lifestyle. Our services include tailored nutrition plans, personalised fitness
# programmes and exclusive health advice. We are committed to helping individuals
# stay fit and healthy, enabling them to live their best lives.
# --------------------------------------------------
# Name: B-Fit. The Revolutionary Way to Health.
# Business Idea: B-Fit is an online health and wellness platform designed to make
# it easy for millennials to access the latest and most effective health and
# wellness products, services, and advice. We offer a tailored and personalized
# approach to health and wellness, leveraging the latest technology to deliver
# convenient and innovative solutions to our users. We are here to help
# millennials reach their goals and live their best lives.
# --------------------------------------------------
# Name: GenX Health+ "Revolutionizing Health for Generation X"
# Business Idea: GenX Health+ is an e-commerce startup based in London, providing
# health-related products and services specifically tailored to Generation X. Our
# innovative platform will provide access to health-related advice, specialized
# products, and self-care programs to empower our customers to take charge of
# their well-being. Funded through seed investment, GenX Health+ is set to
# revolutionize the health industry.
# --------------------------------------------------
# Name: Fit4Life – "Healthy Living for Millennials"
# Business Idea: Fit4Life is an e-commerce platform dedicated to health-conscious
# millennials. We offer a wide variety of organic and vegan products, as well as
# fitness equipment, nutrition advice, and lifestyle guidance. We provide an easy-
# to-use platform for customers to access health-related products and services at
# the click of a button. Fit4Life is a London-based startup, funded through seed
# and is the perfect solution for millennials looking to stay healthy and fit.
# --------------------------------------------------
# Name: "VitaGenX" - "Live Your Best Life"
# Business Idea: VitaGenX is an e-commerce startup that provides tailored health
# and wellness solutions for Generation X. Our solutions are evidence-based and
# delivered through a combination of online tools, support, and products. We focus
# on helping our customers reach their goals, so they can live their best life.
# --------------------------------------------------
# Name: "Healr - Take Care of Yourself"
# Business Idea: Healr is an innovative e-commerce platform that offers
# comprehensive health and wellness services to millennials and other segments.
# Our mission is to make it easier for customers to access personalized health and
# wellness services through our online platform. We provide tailored nutrition
# plans, health coaching, and wellness advice to help our customers achieve their
# health and well-being goals. We are based in Berlin and funded through seed.
# --------------------------------------------------
